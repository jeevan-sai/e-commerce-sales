# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfsales=pd.read_excel("C:\\Users\\HP 745 G6\\Documents\\ecommerce.xlsx")

# %%
dfsales
# Out:
#        Row ID                  Order ID Order Date   Customer ID  \
# 0       46682    IZ-2012-LW699061-40911 2020-01-03     LW-699061
# 1       10124   US-2012-BT1130518-40912 2020-01-04    BT-1130518
# 2        9067   MX-2012-AW1093031-40912 2020-01-04    AW-1093031
# 3         130   MX-2012-BT1130531-40912 2020-01-04    BT-1130531
# 4       24072   IN-2012-KM1666027-40914 2020-01-06    KM-1666027
# ...       ...                       ...        ...           ...
# 51285   27381   IN-2015-TB2125058-42367 2023-12-29    TB-2125058
# 51286   50758    JO-2015-PT909067-42367 2023-12-29     PT-909067
# 51287   19359   IT-2015-JC1577591-42368 2023-12-30    JC-1577591
# 51288    9475  MX-2015-TC21535132-42369 2023-12-31   TC-21535132
# 51289   31942  CA-2015-CC12430140-42369 2023-12-31  CC-124301402
#
#              Segment              City             State              Country  \
# 0          Corporate             Mosul            Ninawa                 Iraq
# ...

# %%
dfsales.head(5)
# Out:
#    Row ID                 Order ID Order Date Customer ID        Segment  \
# 0   46682   IZ-2012-LW699061-40911 2020-01-03   LW-699061      Corporate
# 1   10124  US-2012-BT1130518-40912 2020-01-04  BT-1130518  Self-Employed
# 2    9067  MX-2012-AW1093031-40912 2020-01-04  AW-1093031  Self-Employed
# 3     130  MX-2012-BT1130531-40912 2020-01-04  BT-1130531  Self-Employed
# 4   24072  IN-2012-KM1666027-40914 2020-01-06  KM-1666027       Consumer
#
#                City             State Country  Country latitude  \
# 0             Mosul            Ninawa    Iraq         33.223191
# 1             Pilar           Alagoas  Brazil        -14.235004
# 2  Santiago de Cuba  Santiago de Cuba    Cuba         21.521757
# 3        Manzanillo            Granma    Cuba         21.521757
# 4           Huadian             Jilin   China         35.861660
#
#    Country longitude         Region        Market  \
# 0          43.679291   Western Asia  Asia Pacific
# ...

# %%
dfsales.isna().sum()
# Out:
# Row ID               0
# Order ID             0
# Order Date           0
# Customer ID          0
# Segment              0
# City                 0
# State                0
# Country              0
# Country latitude     0
# Country longitude    0
# Region               0
# Market               0
# Subcategory          0
# Category             0
# Product              0
# Quantity             0
# Sales                0
# Discount             0
# Profit               0
# dtype: int64

# %%
sns.boxplot(dfsales)
plt.xticks(rotation=45)
plt.show()

# %%
dfsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             51290 non-null  int64
#  1   Order ID           51290 non-null  object
#  2   Order Date         51290 non-null  datetime64[ns]
#  3   Customer ID        51290 non-null  object
#  4   Segment            51290 non-null  object
#  5   City               51290 non-null  object
#  6   State              51290 non-null  object
#  7   Country            51290 non-null  object
#  8   Country latitude   51290 non-null  float64
#  9   Country longitude  51290 non-null  float64
#  10  Region             51290 non-null  object
#  11  Market             51290 non-null  object
#  12  Subcategory        51290 non-null  object
#  13  Category           51290 non-null  object
#  14  Product            51290 non-null  object
# ...

# %%
dfsales.describe()
# Out:
#             Row ID                     Order Date  Country latitude  \
# count  51290.00000                          51290      51290.000000
# mean   25645.50000  2022-05-11 21:26:49.155780608         24.506298
# min        1.00000            2020-01-01 00:00:00        -40.900557
# 25%    12823.25000            2021-06-19 00:00:00         12.879721
# 50%    25645.50000            2022-07-08 00:00:00         35.861660
# 75%    38467.75000            2023-05-22 00:00:00         38.963745
# max    51290.00000            2023-12-31 00:00:00         61.924110
# std    14806.29199                            NaN         24.119393
#
#        Country longitude      Quantity         Sales      Discount  \
# count       51290.000000  51290.000000  51290.000000  51290.000000
# mean           -4.585665      5.415832    127.074946      0.142908
# min          -106.346771      1.000000      2.000000      0.000000
# 25%           -95.712891      2.000000     25.000000      0.000000
# ...

# %%
dfsales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Customer ID', 'Segment', 'City',
#        'State', 'Country', 'Country latitude', 'Country longitude', 'Region',
#        'Market', 'Subcategory', 'Category', 'Product', 'Quantity', 'Sales',
#        'Discount', 'Profit'],
#       dtype='object')

# %%
dcols=['Country latitude', 'Country longitude','Quantity','Sales','Discount','Profit']

# %%
for i in dcols:
    print(i)
# Out:
# Country latitude
# Country longitude
# Quantity
# Sales
# Discount
# Profit

# %%
for i in dcols:
    skew=dfsales[i].skew().round()
    print(i,"-->",skew)
# Out:
# Country latitude --> -1.0
# Country longitude --> 0.0
# Quantity --> 1.0
# Sales --> 6.0
# Discount --> 1.0
# Profit --> 4.0

# %%
for i in dcols:
    sns.displot(dfsales[i])
    plt.show()
    print(i)
# Out:
# Country latitude
# Country longitude
# Quantity
# Sales
# Discount
# Profit

# %%
for i in dcols:
    skew=dfsales[i].skew().round()
    if skew !=0:
        q1=dfsales[i].quantile(0.25)
        q3=dfsales[i].quantile(0.75)
        iqr=q3-q1
        upper=q3+1.5*iqr
        lower=q1-1.5*iqr
        dfsales[i]=dfsales[i].map(lambda x:  upper if x>upper else  lower if x<lower else x)
    else :
        mean=dfsales[i].mean()
        std=dfsales[i].std()
        l=mean-3*std
        u=mean+3*std
        dfsales[i]=dfsales[i].map(lambda x:  u if x>u else l if x<l else x)

# %%
dfsales
# Out:
#        Row ID                  Order ID Order Date   Customer ID  \
# 0       46682    IZ-2012-LW699061-40911 2020-01-03     LW-699061
# 1       10124   US-2012-BT1130518-40912 2020-01-04    BT-1130518
# 2        9067   MX-2012-AW1093031-40912 2020-01-04    AW-1093031
# 3         130   MX-2012-BT1130531-40912 2020-01-04    BT-1130531
# 4       24072   IN-2012-KM1666027-40914 2020-01-06    KM-1666027
# ...       ...                       ...        ...           ...
# 51285   27381   IN-2015-TB2125058-42367 2023-12-29    TB-2125058
# 51286   50758    JO-2015-PT909067-42367 2023-12-29     PT-909067
# 51287   19359   IT-2015-JC1577591-42368 2023-12-30    JC-1577591
# 51288    9475  MX-2015-TC21535132-42369 2023-12-31   TC-21535132
# 51289   31942  CA-2015-CC12430140-42369 2023-12-31  CC-124301402
#
#              Segment              City             State              Country  \
# 0          Corporate             Mosul            Ninawa                 Iraq
# ...

# %%
sns.boxplot(dfsales)
plt.xticks(rotation=45)
plt.show()

# %%
dfsales.head(2)
# Out:
#    Row ID                 Order ID Order Date Customer ID        Segment  \
# 0   46682   IZ-2012-LW699061-40911 2020-01-03   LW-699061      Corporate
# 1   10124  US-2012-BT1130518-40912 2020-01-04  BT-1130518  Self-Employed
#
#     City    State Country  Country latitude  Country longitude         Region  \
# 0  Mosul   Ninawa    Iraq         33.223191          43.679291   Western Asia
# 1  Pilar  Alagoas  Brazil        -14.235004         -51.925280  South America
#
#          Market                   Subcategory   Category  \
# 0  Asia Pacific  bath oils, bubbles and soaks  Body care
# 1         LATAM  bath oils, bubbles and soaks  Body care
#
#                                            Product  Quantity  Sales  Discount  \
# 0           Head & Shoulders Classic Clean Shampoo      14.5  292.5       0.0
# 1  Kiehl's Ultra Facial Overnight Hydrating Masque       2.0   40.0       0.5
#
#    Profit
# 0    62.5
# 1    -4.0

# %%
dfsales.drop(["Country latitude","Country longitude"],axis=1,inplace=True)

# %%
dfsales
# Out:
#        Row ID                  Order ID Order Date   Customer ID  \
# 0       46682    IZ-2012-LW699061-40911 2020-01-03     LW-699061
# 1       10124   US-2012-BT1130518-40912 2020-01-04    BT-1130518
# 2        9067   MX-2012-AW1093031-40912 2020-01-04    AW-1093031
# 3         130   MX-2012-BT1130531-40912 2020-01-04    BT-1130531
# 4       24072   IN-2012-KM1666027-40914 2020-01-06    KM-1666027
# ...       ...                       ...        ...           ...
# 51285   27381   IN-2015-TB2125058-42367 2023-12-29    TB-2125058
# 51286   50758    JO-2015-PT909067-42367 2023-12-29     PT-909067
# 51287   19359   IT-2015-JC1577591-42368 2023-12-30    JC-1577591
# 51288    9475  MX-2015-TC21535132-42369 2023-12-31   TC-21535132
# 51289   31942  CA-2015-CC12430140-42369 2023-12-31  CC-124301402
#
#              Segment              City             State              Country  \
# 0          Corporate             Mosul            Ninawa                 Iraq
# ...

# %%
dfsales["Category"].unique()
# Out:
# array(['Body care', 'Face care', 'Hair care', 'Home and Accessories',
#        'Make up'], dtype=object)

# %%
dfsales["Market"].unique()
# Out:
# array(['Asia Pacific', 'LATAM', 'Europe', 'USCA', 'Africa'], dtype=object)

# %%
dfsales["Subcategory"].unique()
# Out:
# array(['bath oils, bubbles and soaks', 'body moisturizers',
#        'Body soaps and washes', 'face masks and exfoliators',
#        'hand creams', 'Nail care products', 'vitamins and supplements',
#        'face moisturizing products', 'hair colors and toners',
#        'shampoos and conditioners', 'Accessories',
#        'brushes and applicators', 'candles, sprays, diffusers',
#        'fragrances', 'Eye shadows and pencils',
#        'foundations and concealers', 'Lipsticks'], dtype=object)

# %%
dfsales.to_excel('output.xlsx',index=False)

# %%
dfsales
# Out:
#        Row ID                  Order ID Order Date   Customer ID  \
# 0       46682    IZ-2012-LW699061-40911 2020-01-03     LW-699061
# 1       10124   US-2012-BT1130518-40912 2020-01-04    BT-1130518
# 2        9067   MX-2012-AW1093031-40912 2020-01-04    AW-1093031
# 3         130   MX-2012-BT1130531-40912 2020-01-04    BT-1130531
# 4       24072   IN-2012-KM1666027-40914 2020-01-06    KM-1666027
# ...       ...                       ...        ...           ...
# 51285   27381   IN-2015-TB2125058-42367 2023-12-29    TB-2125058
# 51286   50758    JO-2015-PT909067-42367 2023-12-29     PT-909067
# 51287   19359   IT-2015-JC1577591-42368 2023-12-30    JC-1577591
# 51288    9475  MX-2015-TC21535132-42369 2023-12-31   TC-21535132
# 51289   31942  CA-2015-CC12430140-42369 2023-12-31  CC-124301402
#
#              Segment              City             State              Country  \
# 0          Corporate             Mosul            Ninawa                 Iraq
# ...

# %%
dfsales.to_excel("output.xlsx",index=False)
